# %%
Why is python important

# %%
Easy to learn
Versatile

# %%
print("Hello World")
# Out:
# Hello World

# %%
#Comments -> single-line comment
'''
      this is a
         multiline comment
'''
print("y")
# Out:
# y

# %%
#write a program to write your name
print("Vunene Hope Nukeri")
# Out:
# Vunene Hope Nukeri

# %%
name = "PythonCLcoding"
Student = "Vunene Hope"
University = "University of FortHare"
age = "20 years"
Year = 2026
print(name)
print(Student)
print(University)
print(age)
print(Year)
# Out:
# PythonCLcoding
# Vunene Hope
# University of FortHare
# 20 years
# 2026

# %%
name = input("Enter your name:  ")

print("Hello", name)
# Out:
# Enter your name:   Vunene
# Hello Vunene

# %%
age = input("Enter your age:  ")

print("You're", age)
# Out:
# Enter your age:   20
# You're 20

# %%
name = input("Enter your name:  ")
age = input("Enter your age:  ")

print("Name", name)
print("Age",  age)
# Out:
# Enter your name:   Hope
# Enter your age:   20
# Name Hope
# Age 20

# %%
num1 = int(input("Enter the first number:  "))
num2 = int(input("Enter the second number:   "))

sum1 = num1 + num2
print("Sum", sum1)
# Out:
# Enter the first number:   90
# Enter the second number:    25
# Sum 115

# %%
num = int(input("Enter a number"))
print("Square =", num * num)
# Out:
# Enter a number 4
# Square = 16

# %%
# Swap two variables
a = 5
b = 10

print("Before swapping")
print(a,b)

#perform swapping
a, b = b, a
print("after swapping")
print(a,b)
# Out:
# Before swapping
# 5 10
# after swapping
# 10 5

# %%
a = 1
b = 10
print("Before Swapping")
print(a,b)

a, b = b, a
print("after swapping")
print(a,b)
# Out:
# Before Swapping
# 1 10
# after swapping
# 10 1

# %%
from math import pi
radius = float(input("Enter radius: "))
area = pi * radius ** 2
print("Area = ",area)
# Out:
# Enter radius:  2
# Area =  12.566370614359172

# %%
# find the average of of three numbers

a = int(input("Enter the first number:  "))
b = int(input("Enter the second number:  "))
c = int(input("Enter the third number:  "))

avg = (a+b+c) / 3
print("AVG =", avg)
# Out:
# Enter the first number:   10
# Enter the second number:   15
# Enter the third number:   3
# AVG = 9.333333333333334
