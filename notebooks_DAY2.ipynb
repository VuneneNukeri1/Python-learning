# %%
# Variables - the fondamentals of programming 
types of variables
int
type conversion
user inputs
str
float
tuple
bool

# %%
#Variables - containers for storing storage

name = "Hope"
age = 20

# Dynamic Variables

print(name)
print(age)
# Out:
# Hope
# 20

# %%
# python variables naming rules
 can start with letter of an underscore 
can be alphanumeric

# %%
x = 10
print(x)
print(type(x))
# Out:
# 10
# <class 'int'>

# %%
name = "Hope"
print(name)
print(type(name))
# Out:
# Hope
# <class 'str'>

# %%
pi = 3.14
print(type(pi))
# Out:
# <class 'float'>

# %%
y = 8,6
print(type(y))
# Out:
# <class 'tuple'>

# %%
x = 10
name = "Hope"
pi = 3.14
having_studentcard = True

print(type(x))
print(type(name))
print(type(pi))
print(type(having_studentcard))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
# type casting - changing the form of a value
#casting - to give it a form/shape it

x = 4.67
print(type(x))
y = int(x)
print(y)
print(type(y))
# Out:
# <class 'float'>
# 4
# <class 'int'>

# %%
# taking uesr input

x = input()
print(x)
# Out:
#  10
# 10

# %%
x = input("Enter your age: ")
print(x)
# Out:
# Enter your age:  20
# 20

# %%
name = input("Enter your name: ")
surname = input("Enter your surname: ")
print(name)
print(surname)
print(name, surname)

print(type(name))
print(type(surname))
# Out:
# Enter your name:  Vunene
# Enter your surname:  Nukeri
# Vunene
# Nukeri
# Vunene Nukeri
# <class 'str'>
# <class 'str'>
